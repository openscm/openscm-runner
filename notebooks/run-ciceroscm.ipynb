# %% [markdown]
# # Minimal OpenSCM-Runner example with CICERO-SCM

# %%
# NBVAL_IGNORE_OUTPUT
import logging
import os.path

import matplotlib.pyplot as plt
import scmdata

import openscm_runner
from openscm_runner.run import run
from openscm_runner.adapters import CICEROSCM
# Out:
# /data/ubuntu-znicholls/openscm-runner-zn/src/openscm_runner/progress.py:5: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm

# %%
STDERR_INFO_HANDLER = logging.StreamHandler()
FORMATTER = logging.Formatter(
    "%(asctime)s %(name)s %(threadName)s - %(levelname)s:  %(message)s",
    datefmt="%Y-%m-%d %H:%M:%S",
)
STDERR_INFO_HANDLER.setFormatter(FORMATTER)

OPENSCM_RUNNER_LOGGER = logging.getLogger("openscm_runner")
OPENSCM_RUNNER_LOGGER.setLevel(logging.INFO)
OPENSCM_RUNNER_LOGGER.addHandler(STDERR_INFO_HANDLER)

# %%
# NBVAL_IGNORE_OUTPUT
openscm_runner.__version__
# Out:
# '0.3.1+289.ged1e6ba.dirty'

# %%
cicero_scm = CICEROSCM()
cicero_scm.get_version()
# Out:
# 'v2019vCH4'

# %%
# NBVAL_IGNORE_OUTPUT
input_emissions = scmdata.ScmRun(
    os.path.join(
        "..", "tests", "test-data", "rcmip_scen_ssp_world_emissions.csv"
    ),
    lowercase_cols=True,
)

input_emissions.head(30)
# Out:
# time                                                                                                    2015-01-01  \
# model   region scenario                  unit             variable
# AIM/CGE World  ssp370                    Mt BC/yr         Emissions|BC                                    9.727424
#                                          kt C2F6/yr       Emissions|C2F6                                  1.570000
#                                          kt C6F14/yr      Emissions|C6F14                                 0.350000
#                                          kt CF4/yr        Emissions|CF4                                  10.869900
#                                          Mt CH4/yr        Emissions|CH4                                 388.072796
#                                          Mt CO/yr         Emissions|CO                                  934.349885
#                                          Mt CO2/yr        Emissions|CO2|MAGICC AFOLU                   3517.440000
#                                                           Emissions|CO2|MAGICC Fossil and Industrial  35635.286298
#                                          kt HFC125/yr     Emissions|HFC125                               78.790600
#                                          kt HFC134a/yr    Emissions|HFC134a                             201.953400
#                                          kt HFC143a/yr    Emissions|HFC143a                              32.381000
#                                          kt HFC227ea/yr   Emissions|HFC227ea                              3.663300
#                                          kt HFC23/yr      Emissions|HFC23                                14.485700
#                                          kt HFC245fa/yr   Emissions|HFC245fa                             11.728500
#                                          kt HFC32/yr      Emissions|HFC32                                38.579200
#                                          kt HFC4310mee/yr Emissions|HFC4310mee                            1.151600
#                                          kt N2O/yr        Emissions|N2O                               10900.000000
#                                          Mt NH3/yr        Emissions|NH3                                  65.279703
#                                          Mt NOx/yr        Emissions|NOx                                 155.520450
#                                          Mt OC/yr         Emissions|OC                                   34.746024
#                                          kt SF6/yr        Emissions|SF6                                   8.020000
#                                          Mt SO2/yr        Emissions|Sulfur                              100.771167
#                                          Mt VOC/yr        Emissions|VOC                                 227.244819
#                ssp370-lowNTCF-aerchemmip Mt BC/yr         Emissions|BC                                    9.727424
#                                          kt C2F6/yr       Emissions|C2F6                                  1.570000
#                                          kt C6F14/yr      Emissions|C6F14                                 0.350000
#                                          kt CF4/yr        Emissions|CF4                                  10.869900
#                                          Mt CH4/yr        Emissions|CH4                                 388.072796
#                                          Mt CO/yr         Emissions|CO                                  934.349885
#                                          Mt CO2/yr        Emissions|CO2|MAGICC AFOLU                   3517.440000
#
# time                                                                                                    2020-01-01  \
# model   region scenario                  unit             variable
# AIM/CGE World  ssp370                    Mt BC/yr         Emissions|BC                                   10.227893
#                                          kt C2F6/yr       Emissions|C2F6                                  2.018300
#                                          kt C6F14/yr      Emissions|C6F14                                 0.449891
#                                          kt CF4/yr        Emissions|CF4                                  12.751283
#                                          Mt CH4/yr        Emissions|CH4                                 418.454212
#                                          Mt CO/yr         Emissions|CO                                  968.199943
#                                          Mt CO2/yr        Emissions|CO2|MAGICC AFOLU                   3875.091863
#                                                           Emissions|CO2|MAGICC Fossil and Industrial  40932.946361
#                                          kt HFC125/yr     Emissions|HFC125                              154.436090
#                                          kt HFC134a/yr    Emissions|HFC134a                             233.567600
#                                          kt HFC143a/yr    Emissions|HFC143a                              56.247300
#                                          kt HFC227ea/yr   Emissions|HFC227ea                              4.960724
#                                          kt HFC23/yr      Emissions|HFC23                                 2.355200
#                                          kt HFC245fa/yr   Emissions|HFC245fa                             18.894736
#                                          kt HFC32/yr      Emissions|HFC32                                 6.272500
#                                          kt HFC4310mee/yr Emissions|HFC4310mee                            1.143618
#                                          kt N2O/yr        Emissions|N2O                               11774.929915
#                                          Mt NH3/yr        Emissions|NH3                                  68.740214
#                                          Mt NOx/yr        Emissions|NOx                                 166.055266
#                                          Mt OC/yr         Emissions|OC                                   35.840262
#                                          kt SF6/yr        Emissions|SF6                                   8.408800
#                                          Mt SO2/yr        Emissions|Sulfur                               98.602158
#                                          Mt VOC/yr        Emissions|VOC                                 237.021540
#                ssp370-lowNTCF-aerchemmip Mt BC/yr         Emissions|BC                                    9.654149
#                                          kt C2F6/yr       Emissions|C2F6                                  2.018300
#                                          kt C6F14/yr      Emissions|C6F14                                 0.449891
#                                          kt CF4/yr        Emissions|CF4                                  12.751283
#                                          Mt CH4/yr        Emissions|CH4                                 418.454212
#                                          Mt CO/yr         Emissions|CO                                  925.476786
#                                          Mt CO2/yr        Emissions|CO2|MAGICC AFOLU                   3875.091863
#
# time                                                                                                    2030-01-01  \
# model   region scenario                  unit             variable
# AIM/CGE World  ssp370                    Mt BC/yr         Emissions|BC                                   10.687554
#                                          kt C2F6/yr       Emissions|C2F6                                  1.357400
#                                          kt C6F14/yr      Emissions|C6F14                                 0.302626
#                                          kt CF4/yr        Emissions|CF4                                  10.327405
#                                          Mt CH4/yr        Emissions|CH4                                 471.330793
#                                          Mt CO/yr         Emissions|CO                                  985.393828
#                                          Mt CO2/yr        Emissions|CO2|MAGICC AFOLU                   3518.037633
#                                                           Emissions|CO2|MAGICC Fossil and Industrial  49329.321684
#                                          kt HFC125/yr     Emissions|HFC125                              212.358860
#                                          kt HFC134a/yr    Emissions|HFC134a                             199.087200
#                                          Mt CH4/yr        Emissions|CH4                                 515.545705
#                                          Mt CO/yr         Emissions|CO                                  732.376446
#                                          Mt CO2/yr        Emissions|CO2|MAGICC AFOLU                   3161.907297
#
# time                                                                                                    2050-01-01  \
# model   region scenario                  unit             variable
# AIM/CGE World  ssp370                    Mt BC/yr         Emissions|BC                                   10.945712
#                                          kt C2F6/yr       Emissions|C2F6                                  0.663700
#                                          kt C6F14/yr      Emissions|C6F14                                 0.147921
#                                          kt CF4/yr        Emissions|CF4                                   7.783328
#                                          Mt CH4/yr        Emissions|CH4                                 558.974274
#                                          Mt CO/yr         Emissions|CO                                  996.036314
#                                          Mt CO2/yr        Emissions|CO2|MAGICC AFOLU                   2889.126278
#                                                           Emissions|CO2|MAGICC Fossil and Industrial  60014.932344
#                                          kt HFC125/yr     Emissions|HFC125                              282.002550
#                                          kt HFC134a/yr    Emissions|HFC134a                             201.090800
#                                          kt HFC143a/yr    Emissions|HFC143a                             106.882500
#                                          kt HFC227ea/yr   Emissions|HFC227ea                              5.233234
#                                          kt HFC23/yr      Emissions|HFC23                                 0.160300
#                                          kt HFC245fa/yr   Emissions|HFC245fa                             36.911089
#                                          kt HFC32/yr      Emissions|HFC32                                 0.426900
#                                          kt HFC4310mee/yr Emissions|HFC4310mee                            0.530488
#                                          kt N2O/yr        Emissions|N2O                               15634.911664
#                                          Mt NH3/yr        Emissions|NH3                                  80.714002
#                                          Mt NOx/yr        Emissions|NOx                                 169.856025
#                                          Mt OC/yr         Emissions|OC                                   38.379225
#                                          kt SF6/yr        Emissions|SF6                                   8.514200
#                                          Mt SO2/yr        Emissions|Sulfur                               99.777851
#                                          Mt VOC/yr        Emissions|VOC                                 256.014508
#                ssp370-lowNTCF-aerchemmip Mt BC/yr         Emissions|BC                                    5.875750
#                                          kt C2F6/yr       Emissions|C2F6                                  0.663700
#                                          kt C6F14/yr      Emissions|C6F14                                 0.147921
#                                          kt CF4/yr        Emissions|CF4                                   7.783328
#                                          Mt CH4/yr        Emissions|CH4                                 558.974274
#                                          Mt CO/yr         Emissions|CO                                  602.469951
#                                          Mt CO2/yr        Emissions|CO2|MAGICC AFOLU                   2889.126278
#
# time                                                                                                    2060-01-01  \
# model   region scenario                  unit             variable
# AIM/CGE World  ssp370                    Mt BC/yr         Emissions|BC                                   10.581617
#                                          kt C2F6/yr       Emissions|C2F6                                  0.490500
#                                          kt C6F14/yr      Emissions|C6F14                                 0.109300
#                                          kt CF4/yr        Emissions|CF4                                   7.147934
#                                          Mt CH4/yr        Emissions|CH4                                 602.318529
#                                          Mt CO/yr         Emissions|CO                                  969.819813
#                                          Mt CO2/yr        Emissions|CO2|MAGICC AFOLU                   3144.546763
#                                                           Emissions|CO2|MAGICC Fossil and Industrial  63423.820853
#                                          kt HFC125/yr     Emissions|HFC125                              299.827430
#                                          kt HFC134a/yr    Emissions|HFC134a                             203.604500
#                                          kt HFC143a/yr    Emissions|HFC143a                             114.293000
#                                          Mt CH4/yr        Emissions|CH4                                 647.129406
#                                          Mt CO/yr         Emissions|CO                                  532.060408
#                                          Mt CO2/yr        Emissions|CO2|MAGICC AFOLU                   3048.513956
#
# time                                                                                                    2080-01-01  \
# model   region scenario                  unit             variable
# AIM/CGE World  ssp370                    Mt BC/yr         Emissions|BC                                    9.761072
#                                          kt C2F6/yr       Emissions|C2F6                                  0.308700
#                                          kt C6F14/yr      Emissions|C6F14                                 0.068818
#                                          kt CF4/yr        Emissions|CF4                                   6.481040
#                                          Mt CH4/yr        Emissions|CH4                                 693.382453
#                                          Mt CO/yr         Emissions|CO                                  926.132789
#                                          Mt CO2/yr        Emissions|CO2|MAGICC AFOLU                   2843.305300
#                                                           Emissions|CO2|MAGICC Fossil and Industrial  70561.920621
#                                          kt HFC125/yr     Emissions|HFC125                              340.664240
#                                          kt HFC134a/yr    Emissions|HFC134a                             232.340800
#                                          kt HFC143a/yr    Emissions|HFC143a                             133.430100
#                                          kt HFC227ea/yr   Emissions|HFC227ea                              4.467998
#                                          kt HFC23/yr      Emissions|HFC23                                 0.022700
#                                          kt HFC245fa/yr   Emissions|HFC245fa                             49.711190
#                                          kt HFC32/yr      Emissions|HFC32                                 0.060500
#                                          kt HFC4310mee/yr Emissions|HFC4310mee                            0.465773
#                                          kt N2O/yr        Emissions|N2O                               18581.107000
#                                          Mt NH3/yr        Emissions|NH3                                  83.671519
#                                          Mt NOx/yr        Emissions|NOx                                 151.232142
#                                          Mt OC/yr         Emissions|OC                                   35.556500
#                                          kt SF6/yr        Emissions|SF6                                   8.730600
#                                          Mt SO2/yr        Emissions|Sulfur                               87.403154
#                                          Mt VOC/yr        Emissions|VOC                                 241.421792
#                ssp370-lowNTCF-aerchemmip Mt BC/yr         Emissions|BC                                    4.682260
#                                          kt C2F6/yr       Emissions|C2F6                                  0.308700
#                                          kt C6F14/yr      Emissions|C6F14                                 0.068818
#                                          kt CF4/yr        Emissions|CF4                                   6.481040
#                                          Mt CH4/yr        Emissions|CH4                                 693.382453
#                                          Mt CO/yr         Emissions|CO                                  498.984701
#                                          Mt CO2/yr        Emissions|CO2|MAGICC AFOLU                   2843.305300
#
# time                                                                                                    2090-01-01  \
# model   region scenario                  unit             variable
# AIM/CGE World  ssp370                    Mt BC/yr         Emissions|BC                                    9.449638
#                                          kt C2F6/yr       Emissions|C2F6                                  0.182500
#                                          kt C6F14/yr      Emissions|C6F14                                 0.040700
#                                          kt CF4/yr        Emissions|CF4                                   6.018345
#                                          Mt CH4/yr        Emissions|CH4                                 735.323193
#                                          Mt CO/yr         Emissions|CO                                  919.418030
#                                          Mt CO2/yr        Emissions|CO2|MAGICC AFOLU                   2564.936400
#                                                           Emissions|CO2|MAGICC Fossil and Industrial  75234.113021
#                                          kt HFC125/yr     Emissions|HFC125                              358.674180
#                                          kt HFC134a/yr    Emissions|HFC134a                             254.877700
#                                          kt HFC143a/yr    Emissions|HFC143a                             140.363400
#                                          kt HFC227ea/yr   Emissions|HFC227ea                              4.395552
#                                          Mt CO/yr         Emissions|CO                                  438.754040
#                                          Mt CO2/yr        Emissions|CO2|MAGICC AFOLU                   2656.121100

# %%
# NBVAL_IGNORE_OUTPUT
res = run(
    climate_models_cfgs={
        "CICEROSCM": [
            # @marit, how do you get the model to stop in 2100?
            {
                "scenario_end": input_emissions["year"].max(),
                "model_end": input_emissions["year"].max(),
                **cfg,
            }
            for cfg in [
                #             {},  # passing an empty list of an empty dict will do <@marit to write>
                {
                    "Index": 30040,
                    "lambda": 0.540,
                    "akapa": 0.341,
                    "cpi": 0.556,
                    "W": 1.897,
                    "rlamdo": 16.618,
                    "beto": 3.225,
                    "mixed": 107.277,
                    "dirso2_forc": -0.457,
                    "indso2_forc": -0.514,
                    "bc_forc": 0.200,
                    "oc_forc": -0.103,
                },
                {
                    "Index": 1,
                    "lambda": 0.3925,
                    "akapa": 0.2421,
                    "cpi": 0.3745,
                    "W": 0.8172,
                    "rlamdo": 16.4599,
                    "beto": 4.4369,
                    "mixed": 35.4192,
                    "dirso2_forc": -0.3428,
                    "indso2_forc": -0.3856,
                    "bc_forc": 0.1507,
                    "oc_forc": -0.0776,
                },
                #             {"q": np.array([0.3, 0.45]), "r0": 30.0, "lambda_global": 0.9},
                #             {"q": np.array([0.35, 0.4]), "r0": 25.0, "lambda_global": 1.1},
            ]
        ],
    },
    scenarios=input_emissions,
    output_variables=(
        "Surface Air Temperature Change",
        "Atmospheric Concentrations|CO2",
        "Effective Radiative Forcing",
        "Effective Radiative Forcing|CO2",
        "Effective Radiative Forcing|CH4",
        "Effective Radiative Forcing|N2O",
        "Effective Radiative Forcing|Greenhouse Gases",
        "Effective Radiative Forcing|Aerosols",
        "Effective Radiative Forcing|Aerosols|Direct Effect|BC",
        "Effective Radiative Forcing|Aerosols|Direct Effect|OC",
        "Effective Radiative Forcing|Aerosols|Direct Effect|SOx",
        "Effective Radiative Forcing|Aerosols|Direct Effect",
        "Effective Radiative Forcing|Aerosols|Indirect Effect",
    ),
    # not yet implemented
    #     out_config={"CICEROSCM": ("lambda",)}
).filter(
    year=range(1, input_emissions["year"].max() + 1)
)  # TODO: remove filter once we know how to stop the model
# Out:
# Climate models:   0%|          | 0.00/1.00 [00:00<?, ?it/s]
# 2021-04-23 11:47:44 openscm_runner.adapters.ciceroscm_adapter._run_ciceroscm_parallel MainThread - INFO:  Entered _parallel_ciceroscm
# 2021-04-23 11:47:44 openscm_runner.adapters.ciceroscm_adapter._run_ciceroscm_parallel MainThread - INFO:  Running in parallel with up to 64 workers
# Parallel runs:   0%|          | 0.00/10.0 [00:00<?, ?it/s]
# 2021-04-23 11:47:45 openscm_runner.adapters.ciceroscm_adapter.ciceroscm_wrapper MainThread - INFO:  Creating new CICERO-SCM instance: /tmp/ciceroscm-asdzitrl
# 2021-04-23 11:47:45 openscm_runner.adapters.ciceroscm_adapter.ciceroscm_wrapper MainThread - INFO:  Creating new CICERO-SCM instance: /tmp/ciceroscm-nrkc5ogg
# 2021-04-23 11:47:45 openscm_runner.adapters.ciceroscm_adapter.ciceroscm_wrapper MainThread - INFO:  Creating new CICERO-SCM instance: /tmp/ciceroscm-o7ufda4n
# 2021-04-23 11:47:45 openscm_runner.adapters.ciceroscm_adapter.ciceroscm_wrapper MainThread - INFO:  Creating new CICERO-SCM instance: /tmp/ciceroscm-6zlzln1m
# 2021-04-23 11:47:45 openscm_runner.adapters.ciceroscm_adapter
available, using ssp245
# 2021-04-23 11:47:45 openscm_runner.adapters.ciceroscm_adapter.make_scenario_files MainThread - WARNING:  No H-1301 data available, using ssp245
# 2021-04-23 11:47:45 openscm_runner.adapters.ciceroscm_adapter.make_scenario_files MainThread - WARNING:  No H-1301 data available, using ssp245
# 2021-04-23 11:47:45 openscm_runner.adapters.ciceroscm_adapter.make_scenario_files MainThread - WARNING:  No H-1301 data available, using ssp245
# 2021-04-23 11:47:45 openscm_runner.adapters.ciceroscm_adapter.make_scenario_files MainThread - WARNING:  No H-1301 data available, using ssp245
# 2021-04-23 11:47:45 openscm_runner.adapters.ciceroscm_adapter.make_scenario_files MainThread - WARNING:  No H-2402 data available, using ssp245
# 2021-04-23 11:47:45 openscm_runner.adapters.ciceroscm_adapter.make_scenario_files MainThread - WARNING:  No H-2402 data available, using ssp245
# 2021-04-23 11:47:45 openscm_runner.adapters.ciceroscm_adapter.make_scenario_files MainThread - WARNING:  No H-1211 data available, using ssp245
# 2021-04-23 11:47:45 openscm_runner.adapters.ciceroscm_adapter.make_scenario_files MainThread - WARNING:  No H-2402 data available, using ssp245
# 2021-04-23 11:47:45 openscm_runner.adapters.ciceroscm_adapter.make_scenario_files MainThread - WARNING:  No H-2402 data available, using ssp245
# 2021-04-23 11:47:45 openscm_runner.adapters.ciceroscm_adapter.make_scenario_files MainThread - WARNING:  No H-2402 data available, using ssp245
# 2021-04-23 11:47:45 openscm_runner.adapters.ciceroscm_adapter.make_scenario_files MainThread - WARNING:  No H-2402 data available, using ssp245
# 2021-04-23 11:47:45 openscm_runner.adapters.ciceroscm_adapter.make_scenario_files MainThread - WARNING:  No H-2402 data available, using ssp245
# 2021-04-23 11:47:45 openscm_runner.adapters.ciceroscm_adapter.make_scenario_files MainThread - WARNING:  No H-1301 data available, using ssp245
# 2021-04-23 11:47:45 openscm_runner.adapters.ciceroscm_adapter.make_scenario_files MainThread - WARNING:  No BMB_AEROS_BC data available, using ssp245
# 2021-04-23 11:47:45 openscm_runner.adapters.ciceroscm_adapter.make_scenario_files MainThread - WARNING:  No BMB_AEROS_OC data available, using ssp245
# 2021-04-23 11:47:45 openscm_runner.adapters.ciceroscm_adapter.make_scenario_files MainThread - WARNING:  No H-2402 data available, using ssp245
# 2021-04-23 11:47:45 openscm_runner.adapters.ciceroscm_adapter.make_scenario_files MainThread - WARNING:  No BMB_AEROS_BC data available, using ssp245
# 2021-04-23 11:47:45 openscm_runner.adapters.ciceroscm_adapter.make_scenario_files MainThread - WARNING:  No BMB_AEROS_OC data available, using ssp245
# 2021-04-23 11:47:45 openscm_runner.adapters.ciceroscm_adapter.make_scenario_files MainThread - WARNING:  No BMB_AEROS_BC data available, using ssp245
# 2021-04-23 11:47:45 openscm_runner.adapters.ciceroscm_adapter.make_scenario_files MainThread - WARNING:  No BMB_AEROS_BC data available, using ssp245
# 2021-04-23 11:47:45 openscm_runner.adapters.ciceroscm_adapter.make_scenario_files MainThread - WARNING:  No BMB_AEROS_BC data available, using ssp245
# 2021-04-23 11:47:45 openscm_runner.adapters.ciceroscm_adapter.make_scenario_files MainThread - WARNING:  No BMB_AEROS_BC data available, using ssp245
# 2021-04-23 11:47:45 openscm_runner.adapters.ciceroscm_adapter.make_scenario_files MainThread - WARNING:  No BMB_AEROS_BC data available, using ssp245
# 2021-04-23 11:47:45 openscm_runner.adapters.ciceroscm_adapter.make_scenario_files MainThread - WARNING:  No BMB_AEROS_BC data available, using ssp245
# 2021-04-23 11:47:45 openscm_runner.adapters.ciceroscm_adapter.make_scenario_files MainThread - WARNING:  No BMB_AEROS_OC data available, using ssp245
# 2021-04-23 11:47:45 openscm_runner.adapters.ciceroscm_adapter.make_scenario_files MainThread - WARNING:  No BMB_AEROS_OC data available, using ssp245
# 2021-04-23 11:47:45 openscm_runner.adapters.ciceroscm_adapter.make_scenario_files MainThread - WARNING:  No BMB_AEROS_OC data available, using ssp245
# 2021-04-23 11:47:45 openscm_runner.adapters.ciceroscm_adapter.make_scenario_files MainThread - WARNING:  No BMB_AEROS_OC data available, using ssp245
# 2021-04-23 11:47:45 openscm_runner.adapters.ciceroscm_adapter.make_scenario_files MainThread - WARNING:  No BMB_AEROS_OC data available, using ssp245
# 2021-04-23 11:47:45 openscm_runner.adapters.ciceroscm_adapter.make_scenario_files MainThread - WARNING:  No BMB_AEROS_OC data available, using ssp245
# 2021-04-23 11:47:45 openscm_runner.adapters.ciceroscm_adapter.make_scenario_files MainThread - WARNING:  No BMB_AEROS_BC data available, using ssp245
# 2021-04-23 11:47:45 openscm_runner.adapters.ciceroscm_adapter.make_scenario_files MainThread - WARNING:  No BMB_AEROS_OC data available, using ssp245
# 2021-04-23 11:47:45 openscm_runner.adapters.ciceroscm_adapter.make_scenario_files MainThread - WARNING:  No BMB_AEROS_BC data available, using ssp245
# 2021-04-23 11:47:45 openscm_runner.adapters.ciceroscm_adapter.make_scenario_files MainThread - WARNING:  No BMB_AEROS_OC data available, using ssp245
# 2021-04-23 11:47:48 openscm_runner.adapters.ciceroscm_adapter.ciceroscm_wrapper MainThread - INFO:  Removing CICERO-SCM instance: /tmp/ciceroscm-y6qwc49n
# 2021-04-23 11:47:48 openscm_runner.adapters.ciceroscm_adapter.ciceroscm_wrapper MainThread - INFO:  Removing CICERO-SCM instance: /tmp/ciceroscm-nrkc5ogg
# 2021-04-23 11:47:48 openscm_runner.adapters.ciceroscm_adapter.ciceroscm_wrapper MainThread - INFO:  Removing CICERO-SCM instance: /tmp/ciceroscm-qqtlyv7r
# 2021-04-23 11:47:48 openscm_runner.adapters.ciceroscm_adapter.ciceroscm_wrapper MainThread - INFO:  Removing CICERO-SCM instance: /tmp/ciceroscm-asdzitrl
# 2021-04-23 11:47:48 openscm_runner.adapters.ciceroscm_adapter.ciceroscm_wrapper MainThread - INFO:  Removing CICERO-SCM instance: /tmp/ciceroscm-bu9sfq6o
# 2021-04-23 11:47:48 openscm_runner.adapters.ciceroscm_adapter.ciceroscm_wrapper MainThread - INFO:  Removing CICERO-SCM instance: /tmp/ciceroscm-6zlzln1m
# 2021-04-23 11:47:48 openscm_runner.adapters.ciceroscm_adapter.ciceroscm_wrapper MainThread - INFO:  Removing CICERO-SCM instance: /tmp/ciceroscm-o7ufda4n
# 2021-04-23 11:47:48 openscm_runner.adapters.ciceroscm_adapter.ciceroscm_wrapper MainThread - INFO:  Removing CICERO-SCM instance: /tmp/ciceroscm-19a7qleh
# 2021-04-23 11:47:48 openscm_runner.adapters.ciceroscm_adapter.ciceroscm_wrapper MainThread - INFO:  Removing CICERO-SCM instance: /tmp/ciceroscm-5g0fwu6c
# 2021-04-23 11:47:48 openscm_runner.adapters.ciceroscm_adapter.ciceroscm_wrapper MainThread - INFO:  Removing CICERO-SCM instance: /tmp/ciceroscm-jje624nt
# 2021-04-23 11:47:48 openscm_runner.adapters.ciceroscm_adapter._run_ciceroscm_parallel MainThread - INFO:  Appending CICERO-SCM results into a single ScmRun
# 2021-04-23 11:47:48 openscm_runner.adapters.ciceroscm_adapter._run_ciceroscm_parallel MainThread - INFO:  Shutting down parallel pool
# 2021-04-23 11:47:48 openscm_runner.run MainThread - INFO:  Only one model run, returning its results

# %%
res.head()
# Out:
# time                                                                              1750-01-01  \
# climate_model model region run_id scenario unit  variable
# CICERO-SCM    IMAGE World  30040  ssp119   K     Surface Air Temperature Change     0.063626
#                                            ppm   Atmospheric Concentrations|CO2   278.038000
#                                            W/m^2 Effective Radiative Forcing        0.242147
#                                                  Effective Radiative Forcing|CO2    0.000000
#                                                  Effective Radiative Forcing|CH4    0.000000
#
# time                                                                              1751-01-01  \
# climate_model model region run_id scenario unit  variable
# CICERO-SCM    IMAGE World  30040  ssp119   K     Surface Air Temperature Change     0.096738
#                                            ppm   Atmospheric Concentrations|CO2   278.072000
#                                            W/m^2 Effective Radiative Forcing        0.224856
#                                                  Effective Radiative Forcing|CO2    0.000659
#                                                  Effective Radiative Forcing|CH4    0.001164
#
# time                                                                              1752-01-01  \
# climate_model model region run_id scenario unit  variable
# CICERO-SCM    IMAGE World  30040  ssp119   K     Surface Air Temperature Change     0.118004
#                                            ppm   Atmospheric Concentrations|CO2   278.105000
#                                            W/m^2 Effective Radiative Forcing        0.195780
#                                                  Effective Radiative Forcing|CO2    0.001281
#                                                  Effective Radiative Forcing|CH4    0.002187
#
# time                                                                              1753-01-01  \
# climate_model model region run_id scenario unit  variable
# CICERO-SCM    IMAGE World  30040  ssp119   K     Surface Air Temperature Change     0.131565
#                                            ppm   Atmospheric Concentrations|CO2   278.136000
#                                            W/m^2 Effective Radiative Forcing        0.160532
#                                                  Effective Radiative Forcing|CO2    0.001877
#                                                  Effective Radiative Forcing|CH4    0.003174
#
# time                                                                              1754-01-01  \
# climate_model model region run_id scenario unit  variable
# CICERO-SCM    IMAGE World  30040  ssp119   K     Surface Air Temperature Change     0.139758
#                                            ppm   Atmospheric Concentrations|CO2   278.167000
#                                            W/m^2 Effective Radiative Forcing        0.127257
#                                                  Effective Radiative Forcing|CO2    0.002455
#                                                  Effective Radiative Forcing|CH4    0.004185
#
# time                                                                              1755-01-01  \
# climate_model model region run_id scenario unit  variable
# CICERO-SCM    IMAGE World  30040  ssp119   K     Surface Air Temperature Change     0.142095
#                                            ppm   Atmospheric Concentrations|CO2   278.196000
#                                            W/m^2 Effective Radiative Forcing        0.079029
#                                                  Effective Radiative Forcing|CO2    0.003019
#                                                  Effective Radiative Forcing|CH4    0.004773
#
# time                                                                              1756-01-01  \
# climate_model model region run_id scenario unit  variable
# CICERO-SCM    IMAGE World  30040  ssp119   K     Surface Air Temperature Change     0.119819
#                                            ppm   Atmospheric Concentrations|CO2   278.225000
#                                            W/m^2 Effective Radiative Forcing       -0.153836
#                                                  Effective Radiative Forcing|CO2    0.003574
#                                                  Effective Radiative Forcing|CH4    0.005277
#
# time                                                                              1757-01-01  \
# climate_model model region run_id scenario unit  variable
# CICERO-SCM    IMAGE World  30040  ssp119   K     Surface Air Temperature Change     0.126276
#                                            ppm   Atmospheric Concentrations|CO2   278.254000
#                                            W/m^2 Effective Radiative Forcing       -0.003214
#                                                  Effective Radiative Forcing|CO2    0.004122
#                                                  Effective Radiative Forcing|CH4    0.005610
#
# time                                                                              1758-01-01  \
# climate_model model region run_id scenario unit  variable
# CICERO-SCM    IMAGE World  30040  ssp119   K     Surface Air Temperature Change     0.140735
#                                            ppm   Atmospheric Concentrations|CO2   278.282000
#                                            W/m^2 Effective Radiative Forcing        0.126686
#                                                  Effective Radiative Forcing|CO2    0.004664
#                                                  Effective Radiative Forcing|CH4    0.005868
#
# time                                                                              1759-01-01  \
# climate_model model region run_id scenario unit  variable
# CICERO-SCM    IMAGE World  30040  ssp119   K     Surface Air Temperature Change     0.157538
#                                            ppm   Atmospheric Concentrations|CO2   278.311000
#                                            W/m^2 Effective Radiative Forcing        0.205593
#                                                  Effective Radiative Forcing|CO2    0.005201
#                                                  Effective Radiative Forcing|CH4    0.006156
#
# time                                                                              ...  \
# climate_model model region run_id scenario unit  variable                         ...
# CICERO-SCM    IMAGE World  30040  ssp119   K     Surface Air Temperature Change   ...
#                                            ppm   Atmospheric Concentrations|CO2   ...
#                                            W/m^2 Effective Radiative Forcing      ...
#                                                  Effective Radiative Forcing|CO2  ...
#                                                  Effective Radiative Forcing|CH4  ...
#
# time                                                                              2091-01-01  \
# climate_model model region run_id scenario unit  variable
# CICERO-SCM    IMAGE World  30040  ssp119   K     Surface Air Temperature Change     1.256350
#                                            ppm   Atmospheric Concentrations|CO2   380.429000
#                                            W/m^2 Effective Radiative Forcing        2.059799
#                                                  Effective Radiative Forcing|CO2    1.682220
#                                                  Effective Radiative Forcing|CH4    0.094703
#
# time                                                                              2092-01-01  \
# climate_model model region run_id scenario unit  variable
# CICERO-SCM    IMAGE World  30040  ssp119   K     Surface Air Temperature Change     1.253040
#                                            ppm   Atmospheric Concentrations|CO2   379.085000
#                                            W/m^2 Effective Radiative Forcing        2.067507
#                                                  Effective Radiative Forcing|CO2    1.662950
#                                                  Effective Radiative Forcing|CH4    0.092850
#
# time                                                                              2093-01-01  \
# climate_model model region run_id scenario unit  variable
# CICERO-SCM    IMAGE World  30040  ssp119   K     Surface Air Temperature Change     1.248740
#                                            ppm   Atmospheric Concentrations|CO2   377.729000
#                                            W/m^2 Effective Radiative Forcing        2.037565
#                                                  Effective Radiative Forcing|CO2    1.643440
#                                                  Effective Radiative Forcing|CH4    0.091027
#
# time                                                                              2094-01-01  \
# climate_model model region run_id scenario unit  variable
# CICERO-SCM    IMAGE World  30040  ssp119   K     Surface Air Temperature Change     1.241300
#                                            ppm   Atmospheric Concentrations|CO2   376.361000
#                                            W/m^2 Effective Radiative Forcing        1.996138
#                                                  Effective Radiative Forcing|CO2    1.623700
#                                                  Effective Radiative Forcing|CH4    0.089231
#
# time                                                                              2095-01-01  \
# climate_model model region run_id scenario unit  variable
# CICERO-SCM    IMAGE World  30040  ssp119   K     Surface Air Temperature Change     1.231980
#                                            ppm   Atmospheric Concentrations|CO2   374.981000
#                                            W/m^2 Effective Radiative Forcing        1.959133
#                                                  Effective Radiative Forcing|CO2    1.603710
#                                                  Effective Radiative Forcing|CH4    0.087459
#
# time                                                                              2096-01-01  \
# climate_model model region run_id scenario unit  variable
# CICERO-SCM    IMAGE World  30040  ssp119   K     Surface Air Temperature Change     1.221530
#                                            ppm   Atmospheric Concentrations|CO2   373.590000
#                                            W/m^2 Effective Radiative Forcing        1.918960
#                                                  Effective Radiative Forcing|CO2    1.583490
#                                                  Effective Radiative Forcing|CH4    0.085709
#
# time                                                                              2097-01-01  \
# climate_model model region run_id scenario unit  variable
# CICERO-SCM    IMAGE World  30040  ssp119   K     Surface Air Temperature Change     1.210720
#                                            ppm   Atmospheric Concentrations|CO2   372.186000
#                                            W/m^2 Effective Radiative Forcing        1.892205
#                                                  Effective Radiative Forcing|CO2    1.563030
#                                                  Effective Radiative Forcing|CH4    0.083977
#
# time                                                                              2098-01-01  \
# climate_model model region run_id scenario unit  variable
# CICERO-SCM    IMAGE World  30040  ssp119   K     Surface Air Temperature Change     1.200290
#                                            ppm   Atmospheric Concentrations|CO2   370.770000
#                                            W/m^2 Effective Radiative Forcing        1.865759
#                                                  Effective Radiative Forcing|CO2    1.542320
#                                                  Effective Radiative Forcing|CH4    0.082263
#
# time                                                                              2099-01-01  \
# climate_model model region run_id scenario unit  variable
# CICERO-SCM    IMAGE World  30040  ssp119   K     Surface Air Temperature Change     1.190730
#                                            ppm   Atmospheric Concentrations|CO2   369.343000
#                                            W/m^2 Effective Radiative Forcing        1.855185
#                                                  Effective Radiative Forcing|CO2    1.521370
#                                                  Effective Radiative Forcing|CH4    0.080563
#
# time                                                                              2100-01-01
# climate_model model region run_id scenario unit  variable
# CICERO-SCM    IMAGE World  30040  ssp119   K     Surface Air Temperature Change     1.183160
#                                            ppm   Atmospheric Concentrations|CO2   367.904000
#                                            W/m^2 Effective Radiative Forcing        1.856800
#                                                  Effective Radiative Forcing|CO2    1.500180
#                                                  Effective Radiative Forcing|CH4    0.078877
#
# [5 rows x 351 columns]

# %%
res.tail()
# Out:
# time                                                                                                         1750-01-01  \
# climate_model model         region run_id scenario unit  variable
# CICERO-SCM    REMIND-MAGPIE World  1      ssp585   W/m^2 Effective Radiative Forcing|Aerosols|Direct Eff...    0.014109
#                                                          Effective Radiative Forcing|Aerosols|Direct Eff...   -0.011734
#                                                          Effective Radiative Forcing|Aerosols|Direct Eff...   -0.007191
#                                                          Effective Radiative Forcing|Aerosols|Direct Effect   -0.004817
#                                                          Effective Radiative Forcing|Aerosols|Indirect E...   -0.008089
#
# time                                                                                                         1751-01-01  \
# climate_model model         region run_id scenario unit  variable
# CICERO-SCM    REMIND-MAGPIE World  1      ssp585   W/m^2 Effective Radiative Forcing|Aerosols|Direct Eff...    0.013978
#                                                          Effective Radiative Forcing|Aerosols|Direct Eff...   -0.011662
#                                                          Effective Radiative Forcing|Aerosols|Direct Eff...   -0.007098
#                                                          Effective Radiative Forcing|Aerosols|Direct Effect   -0.004782
#                                                          Effective Radiative Forcing|Aerosols|Indirect E...   -0.007984
#
# time                                                                                                         1752-01-01  \
# climate_model model         region run_id scenario unit  variable
# CICERO-SCM    REMIND-MAGPIE World  1      ssp585   W/m^2 Effective Radiative Forcing|Aerosols|Direct Eff...    0.013979
#                                                          Effective Radiative Forcing|Aerosols|Direct Eff...   -0.011675
#                                                          Effective Radiative Forcing|Aerosols|Direct Eff...   -0.007065
#                                                          Effective Radiative Forcing|Aerosols|Direct Effect   -0.004761
#                                                          Effective Radiative Forcing|Aerosols|Indirect E...   -0.007947
#
# time                                                                                                         1753-01-01  \
# climate_model model         region run_id scenario unit  variable
# CICERO-SCM    REMIND-MAGPIE World  1      ssp585   W/m^2 Effective Radiative Forcing|Aerosols|Direct Eff...    0.014087
#                                                          Effective Radiative Forcing|Aerosols|Direct Eff...   -0.011758
#                                                          Effective Radiative Forcing|Aerosols|Direct Eff...   -0.007105
#                                                          Effective Radiative Forcing|Aerosols|Direct Effect   -0.004775
#                                                          Effective Radiative Forcing|Aerosols|Indirect E...   -0.007992
#
# time                                                                                                         1754-01-01  \
# climate_model model         region run_id scenario unit  variable
# CICERO-SCM    REMIND-MAGPIE World  1      ssp585   W/m^2 Effective Radiative Forcing|Aerosols|Direct Eff...    0.014265
#                                                          Effective Radiative Forcing|Aerosols|Direct Eff...   -0.011886
#                                                          Effective Radiative Forcing|Aerosols|Direct Eff...   -0.007256
#                                                          Effective Radiative Forcing|Aerosols|Direct Effect   -0.004876
#                                                          Effective Radiative Forcing|Aerosols|Indirect E...   -0.008162
#
# time                                                                                                         1755-01-01  \
# climate_model model         region run_id scenario unit  variable
# CICERO-SCM    REMIND-MAGPIE World  1      ssp585   W/m^2 Effective Radiative Forcing|Aerosols|Direct Eff...    0.014199
#                                                          Effective Radiative Forcing|Aerosols|Direct Eff...   -0.011855
#                                                          Effective Radiative Forcing|Aerosols|Direct Eff...   -0.007198
#                                                          Effective Radiative Forcing|Aerosols|Direct Effect   -0.004854
#                                                          Effective Radiative Forcing|Aerosols|Indirect E...   -0.008097
#
# time                                                                                                         1756-01-01  \
# climate_model model         region run_id scenario unit  variable
# CICERO-SCM    REMIND-MAGPIE World  1      ssp585   W/m^2 Effective Radiative Forcing|Aerosols|Direct Eff...    0.014225
#                                                          Effective Radiative Forcing|Aerosols|Direct Eff...   -0.011881
#                                                          Effective Radiative Forcing|Aerosols|Direct Eff...   -0.007130
#                                                          Effective Radiative Forcing|Aerosols|Direct Effect   -0.004786
#                                                          Effective Radiative Forcing|Aerosols|Indirect E...   -0.008020
#
# time                                                                                                         1757-01-01  \
# climate_model model         region run_id scenario unit  variable
# CICERO-SCM    REMIND-MAGPIE World  1      ssp585   W/m^2 Effective Radiative Forcing|Aerosols|Direct Eff...    0.014460
#                                                          Effective Radiative Forcing|Aerosols|Direct Eff...   -0.012046
#                                                          Effective Radiative Forcing|Aerosols|Direct Eff...   -0.007390
#                                                          Effective Radiative Forcing|Aerosols|Direct Effect   -0.004976
#                                                          Effective Radiative Forcing|Aerosols|Indirect E...   -0.008312
#
# time                                                                                                         1758-01-01  \
# climate_model model         region run_id scenario unit  variable
# CICERO-SCM    REMIND-MAGPIE World  1      ssp585   W/m^2 Effective Radiative Forcing|Aerosols|Direct Eff...    0.014223
#                                                          Effective Radiative Forcing|Aerosols|Direct Eff...   -0.011905
#                                                          Effective Radiative Forcing|Aerosols|Direct Eff...   -0.007308
#                                                          Effective Radiative Forcing|Aerosols|Direct Effect   -0.004989
#                                                          Effective Radiative Forcing|Aerosols|Indirect E...   -0.008221
#
# time                                                                                                         1759-01-01  \
# climate_model model         region run_id scenario unit  variable
# CICERO-SCM    REMIND-MAGPIE World  1      ssp585   W/m^2 Effective Radiative Forcing|Aerosols|Direct Eff...    0.014417
#                                                          Effective Radiative Forcing|Aerosols|Direct Eff...   -0.012043
#                                                          Effective Radiative Forcing|Aerosols|Direct Eff...   -0.007290
#                                                          Effective Radiative Forcing|Aerosols|Direct Effect   -0.004915
#                                                          Effective Radiative Forcing|Aerosols|Indirect E...   -0.008200
#
# time                                                                                                         ...  \
# climate_model model         region run_id scenario unit  variable                                            ...
# CICERO-SCM    REMIND-MAGPIE World  1      ssp585   W/m^2 Effective Radiative Forcing|Aerosols|Direct Eff...  ...
#                                                          Effective Radiative Forcing|Aerosols|Direct Eff...  ...
#                                                          Effective Radiative Forcing|Aerosols|Direct Eff...  ...
#                                                          Effective Radiative Forcing|Aerosols|Direct Effect  ...
#                                                          Effective Radiative Forcing|Aerosols|Indirect E...  ...
#
# time                                                                                                         2091-01-01  \
# climate_model model         region run_id scenario unit  variable
# CICERO-SCM    REMIND-MAGPIE World  1      ssp585   W/m^2 Effective Radiative Forcing|Aerosols|Direct Eff...    0.081401
#                                                          Effective Radiative Forcing|Aerosols|Direct Eff...   -0.072779
#                                                          Effective Radiative Forcing|Aerosols|Direct Eff...   -0.119927
#                                                          Effective Radiative Forcing|Aerosols|Direct Effect   -0.111305
#                                                          Effective Radiative Forcing|Aerosols|Indirect E...   -0.134900
#
# time                                                                                                         2092-01-01  \
# climate_model model         region run_id scenario unit  variable
# CICERO-SCM    REMIND-MAGPIE World  1      ssp585   W/m^2 Effective Radiative Forcing|Aerosols|Direct Eff...    0.079334
#                                                          Effective Radiative Forcing|Aerosols|Direct Eff...   -0.072532
#                                                          Effective Radiative Forcing|Aerosols|Direct Eff...   -0.116266
#                                                          Effective Radiative Forcing|Aerosols|Direct Effect   -0.109465
#                                                          Effective Radiative Forcing|Aerosols|Indirect E...   -0.130783
#
# time                                                                                                         2093-01-01  \
# climate_model model         region run_id scenario unit  variable
# CICERO-SCM    REMIND-MAGPIE World  1      ssp585   W/m^2 Effective Radiative Forcing|Aerosols|Direct Eff...    0.077266
#                                                          Effective Radiative Forcing|Aerosols|Direct Eff...   -0.072286
#                                                          Effective Radiative Forcing|Aerosols|Direct Eff...   -0.112606
#                                                          Effective Radiative Forcing|Aerosols|Direct Effect   -0.107625
#                                                          Effective Radiative Forcing|Aerosols|Indirect E...   -0.126665
#
# time                                                                                                         2094-01-01  \
# climate_model model         region run_id scenario unit  variable
# CICERO-SCM    REMIND-MAGPIE World  1      ssp585   W/m^2 Effective Radiative Forcing|Aerosols|Direct Eff...    0.075199
#                                                          Effective Radiative Forcing|Aerosols|Direct Eff...   -0.072039
#                                                          Effective Radiative Forcing|Aerosols|Direct Eff...   -0.108945
#                                                          Effective Radiative Forcing|Aerosols|Direct Effect   -0.105785
#                                                          Effective Radiative Forcing|Aerosols|Indirect E...   -0.122548
#
# time                                                                                                         2095-01-01  \
# climate_model model         region run_id scenario unit  variable
# CICERO-SCM    REMIND-MAGPIE World  1      ssp585   W/m^2 Effective Radiative Forcing|Aerosols|Direct Eff...    0.073132
#                                                          Effective Radiative Forcing|Aerosols|Direct Eff...   -0.071792
#                                                          Effective Radiative Forcing|Aerosols|Direct Eff...   -0.105285
#                                                          Effective Radiative Forcing|Aerosols|Direct Effect   -0.103946
#                                                          Effective Radiative Forcing|Aerosols|Indirect E...   -0.118430
#
# time                                                                                                         2096-01-01  \
# climate_model model         region run_id scenario unit  variable
# CICERO-SCM    REMIND-MAGPIE World  1      ssp585   W/m^2 Effective Radiative Forcing|Aerosols|Direct Eff...    0.071064
#                                                          Effective Radiative Forcing|Aerosols|Direct Eff...   -0.071546
#                                                          Effective Radiative Forcing|Aerosols|Direct Eff...   -0.101625
#                                                          Effective Radiative Forcing|Aerosols|Direct Effect   -0.102107
#                                                          Effective Radiative Forcing|Aerosols|Indirect E...   -0.114313
#
# time                                                                                                         2097-01-01  \
# climate_model model         region run_id scenario unit  variable
# CICERO-SCM    REMIND-MAGPIE World  1      ssp585   W/m^2 Effective Radiative Forcing|Aerosols|Direct Eff...    0.068997
#                                                          Effective Radiative Forcing|Aerosols|Direct Eff...   -0.071299
#                                                          Effective Radiative Forcing|Aerosols|Direct Eff...   -0.097964
#                                                          Effective Radiative Forcing|Aerosols|Direct Effect   -0.100267
#                                                          Effective Radiative Forcing|Aerosols|Indirect E...   -0.110196
#
# time                                                                                                         2098-01-01  \
# climate_model model         region run_id scenario unit  variable
# CICERO-SCM    REMIND-MAGPIE World  1      ssp585   W/m^2 Effective Radiative Forcing|Aerosols|Direct Eff...    0.066929
#                                                          Effective Radiative Forcing|Aerosols|Direct Eff...   -0.071053
#                                                          Effective Radiative Forcing|Aerosols|Direct Eff...   -0.094304
#                                                          Effective Radiative Forcing|Aerosols|Direct Effect   -0.098427
#                                                          Effective Radiative Forcing|Aerosols|Indirect E...   -0.106078
#
# time                                                                                                         2099-01-01  \
# climate_model model         region run_id scenario unit  variable
# CICERO-SCM    REMIND-MAGPIE World  1      ssp585   W/m^2 Effective Radiative Forcing|Aerosols|Direct Eff...    0.064862
#                                                          Effective Radiative Forcing|Aerosols|Direct Eff...   -0.070806
#                                                          Effective Radiative Forcing|Aerosols|Direct Eff...   -0.090643
#                                                          Effective Radiative Forcing|Aerosols|Direct Effect   -0.096587
#                                                          Effective Radiative Forcing|Aerosols|Indirect E...   -0.101961
#
# time                                                                                                         2100-01-01
# climate_model model         region run_id scenario unit  variable
# CICERO-SCM    REMIND-MAGPIE World  1      ssp585   W/m^2 Effective Radiative Forcing|Aerosols|Direct Eff...    0.062795
#                                                          Effective Radiative Forcing|Aerosols|Direct Eff...   -0.070560
#                                                          Effective Radiative Forcing|Aerosols|Direct Eff...   -0.086983
#                                                          Effective Radiative Forcing|Aerosols|Direct Effect   -0.094748
#                                                          Effective Radiative Forcing|Aerosols|Indirect E...   -0.097843
#
# [5 rows x 351 columns]

# %%
plot_kwargs = dict(
    quantiles_plumes=[((0.05, 0.95), 0.5), ((0.5,), 1.0)],
    quantile_over="run_id",
    hue_var="scenario",
    style_var="model",
    style_label="IAM",
    time_axis="year",
)

# %%
# NBVAL_IGNORE_OUTPUT
ax = plt.figure(figsize=(12, 7)).add_subplot(111)
res.filter(variable="Surface Air Temperature Change").plumeplot(
    ax=ax, **plot_kwargs
)
ax.axhline(1.1)
ax.axvline(2018)

# %%
# NBVAL_IGNORE_OUTPUT
ax = plt.figure(figsize=(12, 7)).add_subplot(111)
res.filter(variable="Atmospheric Concentrations|CO2").plumeplot(
    ax=ax, **plot_kwargs
)
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7f788db3e350>,
#  [<matplotlib.patches.Patch at 0x7f788f8c08d0>,
#   <matplotlib.collections.PolyCollection at 0x7f788da87550>,
#   <matplotlib.lines.Line2D at 0x7f788daa8710>,
#   <matplotlib.patches.Patch at 0x7f788daaea10>,
#   <matplotlib.lines.Line2D at 0x7f788f7d9c10>,
#   <matplotlib.lines.Line2D at 0x7f788f781810>,
#   <matplotlib.lines.Line2D at 0x7f788da80150>,
#   <matplotlib.lines.Line2D at 0x7f788da850d0>,
#   <matplotlib.lines.Line2D at 0x7f788da936d0>,
#   <matplotlib.lines.Line2D at 0x7f788dafa710>,
#   <matplotlib.lines.Line2D at 0x7f788dafa790>,
#   <matplotlib.lines.Line2D at 0x7f788db02910>,
#   <matplotlib.lines.Line2D at 0x7f788db02050>,
#   <matplotlib.lines.Line2D at 0x7f788dafaed0>,
#   <matplotlib.patches.Patch at 0x7f788daae8d0>,
#   <matplotlib.lines.Line2D at 0x7f788daae390>,
#   <matplotlib.lines.Line2D at 0x7f788f897050>,
#   <matplotlib.lines.Line2D at 0x7f788daf92d0>,
#   <matplotlib.lines.Line2D at 0x7f788daf9490>,
#   <matplotlib.lines.Line2D at 0x7f788daf9650>])

# %%
# NBVAL_IGNORE_OUTPUT
ax = plt.figure(figsize=(12, 7)).add_subplot(111)
ax, legend_items = res.filter(
    variable="Effective Radiative Forcing*",
    scenario="ssp245",
    year=range(2000, 2030),
).plumeplot(
    quantiles_plumes=[((0.05, 0.95), 0.5), ((0.5,), 1.0)],
    quantile_over="run_id",
    hue_var="variable",
    hue_label="Variable",
    style_var="scenario",
    style_label="Scenario",
    ax=ax,
    time_axis="year",
)
ax.legend(handles=legend_items, ncol=2, loc="center right")
